# %% [markdown]
# <a href="https://colab.research.google.com/github/fc63/gender-classification/blob/main/rus_gender/rus_gender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The sagteam/author_profiling dataset was saved to the pickle file as a dataframe.

# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.5/491.5 kB 11.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 kB 10.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 3.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# ...

# %%
from datasets import load_dataset
import pandas as pd

# Hugging Face üzerinden dataset'i yükle
dataset = load_dataset("sagteam/author_profiling", split="train")

# Hugging Face Dataset nesnesini pandas DataFrame'e dönüştür
df = dataset.to_pandas()

# İlk birkaç satırı göster
print(df.head())
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# author_profiling.py:   0%|          | 0.00/8.69k [00:00<?, ?B/s]
# The repository for sagteam/author_profiling contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/sagteam/author_profiling.
# You can avoid this prompt in future by passing the argument `trust_remote_code=True`.
#
# ...

# %%
df
# Out:
#                      id                                               text  \
# 0         crowdsource_4  здравствуйте. я покупал у вас путевку в тур. я...
# 1         crowdsource_7  Всем приветики ) Меня зовут Лена, На этом сайт...
# 2         crowdsource_8  Уважаемый начальник. Принимая во внимание вашу...
# 3        crowdsource_12  Приветик горячий парень с огненными глазами!Тв...
# 4        crowdsource_13  Добрый день! Мне надоело ваше отношение ко мне...
# ...                 ...                                                ...
# 9559  crowdsource_18881  Привет Серёга. Хочешь оттянуться на этих выход...
# 9560  crowdsource_18882  Доброго здравия, Евгений Абрамович. Как прожив...
# 9561  crowdsource_18892  привет,  для  продолжения  сотрудничества  пре...
# 9562  crowdsource_18893  здарова, погнали чилить в рестик, там и побаза...
# 9563  crowdsource_18894  доброго дня, разрешите ангажировать вас в рест...
#
# ...

# %%
print(df['gender'].value_counts())
# Out:
# gender
# female    4860
# male      4704
# Name: count, dtype: int64

# %%
from google.colab import drive
import pandas as pd

drive.mount('/content/drive')

df_subset = df[['text', 'gender']]

save_path = '/content/drive/MyDrive/datasets/rus_gender.pkl'

df_subset.to_pickle(save_path)

print(f"DataFrame pickle olarak kaydedildi: {save_path}")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# DataFrame pickle olarak kaydedildi: /content/drive/MyDrive/datasets/rus_gender.pkl
